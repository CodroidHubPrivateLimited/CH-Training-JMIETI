# %%
url = "https://www.jmieti.edu.in/"

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [406]>

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# %%
response = requests.get(url,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-62ZY7KHTRP"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-62ZY7KHTRP');
# </script>
# <title>Best Engineering Colleges in India | JMIETI College</title>
# <meta content="Best Engineering Colleges in India, Best Engineering Colleges in Haryana, Best Engineering Colleges in Yamuna Nagar, best engineering colleges in India, b tech colleges in Haryana, top btech colleges in Haryana, Top Engineering Colleges in Haryana, engineering colleges in Haryana, best colleges in Haryana, top btech colleges in Haryana, best colleges for btech" name="Keywords"/>
# <meta content="JMIETI College - One of the Best Engineering Colleges in India, Haryana. Enroll now for top-notch education &amp; bright career opportunities. Apply today!" name="Description"/>
# <meta content="JMIETI College - One of the Best Engineering Colleges in India, Haryana. Enroll now for top-notch education &amp; bright career opportunities. Apply today!" name="Abstract"/><meta content="JMIETI" name="subject"/>
# <meta content="index,follow" name="Robots">
# <meta content="Worldwide" name="Coverage"/>
# <meta content="Global" name="Distribution">
# <meta content="2 days" name="Revisit-After"/>
# <meta content="General" name="Rating"/>
# <meta content="http://www.jmieti.edu.in/" name="url"/>
# <meta content="http://www.jmieti.edu.in/" name="Identifier-URL"/>
# <meta content="info@jmieti.edu.in/" name="Reply-to">
# <meta content="JMIETI" name="Owner">
# <meta content="JMIETI College" name="Author"/>
# <meta content="JMIETI College" name="Publisher"/>
# <meta content="iNet Business Hub" name="Designer">
# <meta content="JMIETI" name="Copyright">
# <meta content="en" name="Language"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <link href="https://www.jmieti.edu.in" rel="canonical"/>
# <meta content="nVGKOJXYO5u9LgW9uDfcsJIvHAAicsjc0R3SWKFhRDY" name="google-site-verification">
# <!-- Meta Tags -->
# <meta content="width=device-width,initial-scale=1.0" name="viewport">
# <meta content="text/html; charset=utf-8" http-equiv="content-type">
# <link href="https://jmieti.edu.in/templates/jmieti/images/favicon.png" rel="shortcut icon" type="image/png"/>
# <link href="https://jmieti.edu.in/templates/jmieti/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Stylesheet -->
# <link href="https://jmieti.edu.in/templates/jmieti/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://jmieti.edu.in/templates/jmieti/css/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://jmieti.edu.in/templates/jmieti/css/animate.css" rel="stylesheet" type="text/css"/>
# <link href="https://jmieti.edu.in/templates/jmieti/css/css-plugin-collections.css" rel="stylesheet"/>
# <link href="https://jmieti.edu.in/templates/jmieti/css/colors/theme-skin-color-set1.css" rel="stylesheet" type="text/css"/>
# <link href="templates/jmieti/css/style-main.css" rel="stylesheet" type="text/css"/>
# <link href="https://jmieti.edu.in/templates/jmieti/css/preloader.css" rel="stylesheet" type="text/css"/>
# <link href="https://jmieti.edu.in/templates/jmieti/css/custom-bootstrap-margin-padding.css" rel="stylesheet" type="text/css"/>
# <!-- CSS | Responsive media queries -->
# <link href="https://jmieti.edu.in/templates/jmieti/css/responsive.css" rel="stylesheet" type="text/css"/>
# <!-- Revolution Slider 5.x CSS settings -->
# <link href="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/css/settings.css" rel="stylesheet" type="text/css">
# <link href="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/css/layers.css" rel="stylesheet" type="text/css">
# <link href="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/css/navigation.css" rel="stylesheet" type="text/css">
# <script src="https://jmieti.edu.in/plugins/jquery.js" type="text/javascript"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.4/jquery.min.js"></script>
# <!-- external javascripts -->
# <!-- Revolution Slider 5.x SCRIPTS -->
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/jquery.themepunch.tools.min.js"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/jquery.themepunch.revolution.min.js"></script>
# <!--[if lt IE 9]>
#   <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#   <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# <![endif]-->
# <link href="https://jmieti.edu.in/templates/jmieti/css/site-icons.css" rel="stylesheet">
# <link href="https://jmieti.edu.in/templates/jmieti/css/mobMenustyle.css" rel="stylesheet">
# <link href="https://jmieti.edu.in/templates/jmieti/css/jquery.mobile-menu.css" rel="stylesheet">
# <link href="https://jmieti.edu.in/plugins/gallery1/gallery.css" media="screen" rel="stylesheet" type="text/css">
# <script src="https://jmieti.edu.in/plugins/validation/jquery.validate.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/plugins/gallery1/jquery.colorbox.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/jquery-plugin-collection.js"></script>
# <!-- Facebook Meta Tags -->
# <meta content="https://www.jmieti.edu.in/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Best Engineering Colleges in India | JMIETI College" property="og:title"/>
# <meta content="JMIETI College - One of the Best Engineering Colleges in India, Haryana. Enroll now for top-notch education &amp; bright career opportunities. Apply today!" property="og:description"/>
# <meta content="https://opengraph.b-cdn.net/production/images/9d875c85-e34b-45f5-91da-55b5b8951554.png?token=c0JatmcBW4RCyJ1xneW6N29b5xUNsuHHuEzPUP4FvdQ&amp;height=500&amp;width=500&amp;expires=33271976114" property="og:image"/>
# <!-- Twitter Meta Tags -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="jmieti.edu.in" property="twitter:domain"/>
# <meta content="https://www.jmieti.edu.in/" property="twitter:url"/>
# <meta content="Best Engineering Colleges in India | JMIETI College" name="twitter:title"/>
# <meta content="JMIETI College - One of the Best Engineering Colleges in India, Haryana. Enroll now for top-notch education &amp; bright career opportunities. Apply today!" name="twitter:description"/>
# <meta content="https://opengraph.b-cdn.net/production/images/9d875c85-e34b-45f5-91da-55b5b8951554.png?token=c0JatmcBW4RCyJ1xneW6N29b5xUNsuHHuEzPUP4FvdQ&amp;height=500&amp;width=500&amp;expires=33271976114" name="twitter:image"/>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org/",
#   "@type": "WebSite",
#   "name": "JMIETI Engineering College",
#   "url": "https://www.jmieti.edu.in",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "{search_term_string}",
#     "query-input": "required name=search_term_string"
#   }
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "name": "JMIETI Engineering College",
#   "url": "https://www.jmieti.edu.in/",
#   "logo": "https://www.jmieti.edu.in/templates/jmieti/images/logo.png",
#   "sameAs": [
#     "https://www.facebook.com/jmietiinstitute",
#     "https://x.com/jmietiradaur",
#     "https://www.instagram.com/jmietiofficial/",
#     "https://www.jmieti.edu.in/"
#   ]
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "LocalBusiness",
#   "name": "Jai Parkash Mukand lal Innovative Engineering and Technology Institute (JMIETI)",
#   "image": "https://www.jmieti.edu.in/templates/jmieti/images/logo.png",
#   "@id": "",
#   "url": "https://www.jmieti.edu.in/",
#   "telephone": "08295905215",
#   "address": {
#     "@type": "PostalAddress",
#     "streetAddress": "Chota Bans, Radaur-135133 (Distt. Yamuna Nagar)",
#     "addressLocality": "Haryana",
#     "postalCode": "135133",
#     "addressCountry": "IN"
#   },
#   "geo": {
#     "@type": "GeoCoordinates",
#     "latitude": 30.034953158976574,
#     "longitude": 77.1598821402132
#   } ,
#   "sameAs": [
#     "https://www.facebook.com/jmietiinstitute",
#     "https://x.com/jmietiradaur",
#     "https://www.instagram.com/jmietiofficial/",
#     "https://www.jmieti.edu.in/"
#   ]
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "Article",
#   "mainEntityOfPage": {
#     "@type": "WebPage",
#     "@id": "https://www.jmieti.edu.in"
#   },
#   "headline": "Best Engineering Colleges in India | College for B Tech in Haryana",
#   "description": "JMIETI College - One of the Best Engineering Colleges in India, Haryana. Enroll now for top-notch education & bright career opportunities. Apply today!",
#   "image": "https://www.jmieti.edu.in/templates/jmieti/images/logo.png",
#   "author": {
#     "@type": "Organization",
#     "name": "JMIETI Engineering Colleges",
#     "url": "https://www.jmieti.edu.in"
#   },
#   "publisher": {
#     "@type": "Organization",
#     "name": "JMIETI Engineering Colleges",
#     "logo": {
#       "@type": "ImageObject",
#       "url": "https://www.jmieti.edu.in/templates/jmieti/images/logo.png"
#     }
#   },
#   "datePublished": "2025-01-04",
#   "dateModified": "2025-01-05"
# }
# </script>
# </link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="has-side-panel side-panel-right fullwidth-page">
# <div class="mobNavigation">
# <div id="page">
# <div class="mm-toggle-wrap">
# <div class="mm-toggle">
# <i class="iconi-menu"></i>
#                 Menu
#             </div>
# <div class="mobsocial">
# <div class="">
# <!--<a href="#" title=""><i class="fab fa-youtube"></i></a>-->
# <a href="https://twitter.com/MukandL" target="_blank" title=""><i class="fa fa-twitter"></i></a>
# <a href="https://www.facebook.com/MukandL/" target="_blank" title=""><i class="fa fa-facebook"></i></a>
# <a href="https://www.instagram.com//" target="_blank"><i class="fa fa-instagram"></i></a>
# <a href="https://www.youtube.com/" target="_blank"><i class="fa fa-youtube"></i></a>
# </div>
# </div>
# </div>
# </div>
# <div id="mobile-menu">
# <ul class="menu">
# <li><a href="https://jmieti.edu.in/">Home</a></li>
# <li><a href="#">About Us</a>
# <ul><li><a href="https://jmieti.edu.in/profile.html" target="_self">Profile</a></li><li><a href="https://jmieti.edu.in/director-message.html" target="_self">Director Message</a></li><li><a href="https://jmieti.edu.in/board-of-governors.html" target="_self">Board of Governors</a></li><li><a href="https://jmieti.edu.in/achievements.html" target="_self">Achievements</a></li><li><a href="https://jmieti.edu.in/demography-of-students.html" target="_self">Demography of Students</a></li></ul> </li>
# <li><a href="#">Society / Social Responsibility</a>
# <ul><li><a href="https://jmieti.edu.in/blood-donation-movement.html" target="_self">Blood Donation Movement</a></li><li><a href="https://jmieti.edu.in/mukand-health-care-project.html" target="_self">Mukand Health Care Project</a></li><li><a href="https://jmieti.edu.in/medical-services.html" target="_self">Medical Services</a></li><li><a href="https://jmieti.edu.in/go-paperless.html" target="_self">Go Paperless</a></li><li><a href="https://jmieti.edu.in/tree-plantation-drives.html" target="_self">Tree Plantation Drives</a></li><li><a href="https://jmieti.edu.in/fee-help.html" target="_self">Fee Help</a></li><li><a href="https://jmieti.edu.in/interest-free-study-loan.html" target="_self">Interest Free Study Loan</a></li><li><a href="https://jmieti.edu.in/charity.html" target="_self">Charity</a></li><li><a href="https://jmieti.edu.in/book-bank-scheme.html" target="_self">Book Bank Scheme</a></li><li><a href="https://jmieti.edu.in/adoption-scheme.html" target="_self">Adoption Scheme</a></li><li><a href="https://jmieti.edu.in/preeti-bhoj.html" target="_self">Preeti Bhoj</a></li></ul> </li>
# <li><a href="#">Administration</a>
# <ul><li><a href="https://jmieti.edu.in/committees.html" target="_self">Committees</a></li><li><a href="https://jmieti.edu.in/whom-to-consult.html" target="_self">Whom to Consult</a></li><li><a href="https://jmieti.edu.in/extension-of-approvals.html" target="_self">Extension of Approvals</a></li><li><a href="https://jmieti.edu.in/mandatory-disclosure.html" target="_self">Mandatory Disclosure</a></li><li><a href="https://jmieti.edu.in/controller-of-examination.html" target="_self">Controller of Examination</a></li><li><a href="https://jmieti.edu.in/finance-officer.html" target="_self">Finance Officer</a></li><li><a href="https://jmieti.edu.in/career.html" target="_self">Career</a></li><li><a href="https://jmieti.edu.in/list-of-holidays-2026.html" target="_self">List of Holidays-2026</a></li></ul> </li>
# <li><a href="#">Academics</a>
# <ul><li><a href="https://jmieti.edu.in/academic-calendar.html" target="_self">Academic Calendar</a></li><li><a href="https://jmieti.edu.in/professional-membershipsmous.html" target="_self">Professional Memberships &amp; MoUs</a></li><li><a href="https://jmieti.edu.in/guest-lecturesworkshops.html" target="_self">Guest Lectures &amp; Workshops</a></li><li><a href="https://jmieti.edu.in/rulesregulations.html" target="_self">Rules &amp; Regulations</a></li><li><a href="https://jmieti.edu.in/ed-cell.html" target="_self">ED Cell</a></li></ul> </li>
# <li><a href="#">Gallery</a>
# <ul><li><a href="https://jmieti.edu.in/photo-gallery.html" target="_self">Photo Gallery</a></li><li><a href="https://jmieti.edu.in/video-gallery.html" target="_self">Video Gallery</a></li><li><a href="https://jmieti.edu.in/media-clippings.html" target="_self">Media Clippings</a></li></ul> </li>
# <li><a href="#">Useful Links</a>
# <ul><li><a href="https://jmieti.edu.in/application-forms.html" target="_self">Application Forms</a></li><li><a href="https://jmieti.edu.in/sc-st-complaint-form.html" target="_self">SC/ ST Complaint Form</a></li><li><a href="https://jmieti.edu.in/online-grievance-redressal28.html" target="_self">Online Grievance Redressal</a></li><li><a href="https://www.jmieti.edu.in/downloads/files/n66a22598c7e8c.pdf" target="_blank">List of Engineering Books</a></li><li><a href="https://jmieti.edu.in/other-links.html" target="_self">Other Links</a></li><li><a href="https://jmieti.edu.in/nirf.html" target="_self">NIRF</a></li><li><a href="https://jmieti.edu.in/social-media-logins111.html" target="_self">Social Media Logins</a></li></ul> </li>
# <li><a href="#">Alumni</a>
# <ul><li><a href="?fn=alumni-meet" target="_self">Interactions</a><ul><li><a href="https://jmieti.edu.in/alumni-meet.html" target="_self">Alumni Meet</a></li><li><a href="https://jmieti.edu.in/placement-activities.html" target="_self">Placement Activities</a></li><li><a href="https://jmieti.edu.in/alumni-entrepreneur.html" target="_self">Alumni Entrepreneur</a></li><li><a href="https://jmieti.edu.in/guest-lectures-and-workshops.html" target="_self">Guest Lectures and Workshops</a></li></ul></li><li><a href="https://jmieti.edu.in/alumni-chapter.html" target="_self">Alumni Chapter</a></li><li><a href="https://jmieti.edu.in/registration-form.html" target="_self">Registration Form</a></li></ul> </li>
# <li><a href="#">Contact Us</a>
# <ul><li><a href="https://jmieti.edu.in/contact-address.html" target="_self">Contact Address</a></li></ul> </li>
# </ul>
# </div>
# </div>
# <div class="clearfix" id="wrapper">
# <!-- Header -->
# <header class="header modern-header modern-header-theme-colored" id="header">
# <div class="header-top sm-text-center">
# <div class="container">
# <div class="row">
# <div class="col-lg-6 col-md-5 col-sm-12">
# <a class="menuzord-brand pull-left sm-pull-center" href="https://jmieti.edu.in/"><img alt="" src="https://jmieti.edu.in/templates/jmieti/images/logo.png"/></a>
# </div>
# <div class="col-lg-6 col-md-7 col-sm-12 sm-pull-center xs-pull-center">
# <div class="widget pull-right sm-pull-none">
# <ul class="nav navbar-nav list-bordered colormenu">
# <li class="dropdown pink">
# <a class="text-theme-colored" href="the-heritage.html"> Mukand Heritage </a>
# <ul class="box-dropdown parent-arrow dropdown-menu">
# <li>
# <div class="bg-pink">
# <div class="mheading">INSIDE Mukand Heritage</div>
# <table class="menu-megabox">
# <tr>
# <td>
# <img alt="" src="https://jmieti.edu.in/templates/jmieti/images/heritage-img.jpg"/>
# <div class="text">
#                                             "Mukand Institutions" have been achieving eminence in the field of Education and Health Care for more than nine decades, and have won accolades and applause of academicians, scholars, corporates, students and the varied sections of the society, for their selfless ...</div>
# <a class="btn btn-dark btn-circled btn-xs" href="the-heritage.html">Read More</a>
# </td>
# <td>
# <ul class="nosubmenu">
# <ul><li><a href="https://jmieti.edu.in/the-heritage.html" target="_self">The Heritage</a></li><li><a href="https://jmieti.edu.in/mukand-resources.html" target="_self">Mukand Resources</a></li><li><a href="https://jmieti.edu.in/mukand-institutions.html" target="_self">Mukand Institutions</a></li><li><a href="https://jmieti.edu.in/mukand-commitment.html" target="_self">Mukand Commitment</a></li><li><a href="https://jmieti.edu.in/kalp-vriksh.html" target="_self">Kalp Vriksh</a></li></ul> </ul>
# </td>
# </tr>
# </table>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown blue">
# <a href="admission-procedure.html"> Admission </a>
# <ul class="box-dropdown parent-arrow dropdown-menu">
# <li>
# <div class="bg-blue">
# <div class="mheading">INSIDE Admission</div>
# <table class="menu-megabox">
# <tr>
# <td>
# <img alt="" src="https://jmieti.edu.in/templates/jmieti/images/admission-img.jpg"/>
# <div class="text">
#                                             Admission to all courses in JMIETI is in accordance with per All India Council for Technical Education (AICTE), Haryana State Technical Education society (HSTES) and KUK. Online counselling is being conducted by Department of Technical Education, Govt...</div>
# <a class="btn btn-dark btn-circled btn-xs" href="admission-procedure.html">Read More</a>
# </td>
# <td>
# <ul class="nosubmenu">
# <ul><li><a href="https://jmieti.edu.in/admission-procedure.html" target="_self">Admission Procedure</a></li><li><a href="https://jmieti.edu.in/coursesintake.html" target="_self">Courses &amp; Intake</a></li><li><a href="https://jmieti.edu.in/fee-structure.html" target="_self">Fee Structure</a></li><li><a href="https://jmieti.edu.in/admission-counseling.html" target="_self">Admission Counseling</a></li><li><a href="https://jmieti.edu.in/admission-brochure.html" target="_self">Admission Brochure</a></li><li><a href="https://jmieti.edu.in/scholarships.html" target="_self">Scholarships</a></li></ul> </ul>
# </td>
# </tr>
# </table>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown red">
# <a href="btech-computer-scienceengineering.html"> Courses </a>
# <ul class="box-dropdown parent-arrow dropdown-menu">
# <li>
# <div class="box-wrapper bg-red">
# <div class="mheading">INSIDE Courses</div>
# <table class="menu-megabox">
# <tr>
# <td>
# <img alt="product" src="https://jmieti.edu.in/templates/jmieti/images/img1.jpg"/>
# <div class="text">
#                                             The pioneering courses that offers a perfect amalgamation of experiential and theoretical studies to build a strong foundation in Engineering &amp; Management and to create all-inclusive learning platform through academic and ...</div>
# <a class="btn btn-dark btn-circled btn-xs" href="btech-computer-scienceengineering.html">Read More</a>
# </td>
# <td>
# <ul class="nosubmenu">
# <ul><li><a href="https://jmieti.edu.in/btech-computer-scienceengineering.html" target="_self">B.Tech. (Computer Science &amp; Engineering)</a><ul><li><a href="https://jmieti.edu.in/overview.html" target="_self">Overview</a></li><li><a href="https://jmieti.edu.in/infrastructure.html" target="_self">Infrastructure</a></li><li><a href="https://jmieti.edu.in/faculty.html" target="_self">Faculty</a></li><li><a href="https://jmieti.edu.in/activities.html" target="_self">Activities</a></li><li><a href="https://jmieti.edu.in/time-table.html" target="_self">Time Table</a></li><li><a href="https://jmieti.edu.in/syllabus.html" target="_self">Syllabus</a></li><li><a href="https://jmieti.edu.in/co-and-lesson-plans67.html" target="_self">CO and Lesson Plans</a></li><li><a href="https://jmieti.edu.in/mentor-mentee-list245.html" target="_self">Mentor-Mentee List</a></li></ul></li><li><a href="https://jmieti.edu.in/btech-computer-scienceengineering-aiml.html" target="_self">B.Tech. (Computer Science &amp; Engineering-AIML)</a><ul><li><a href="https://jmieti.edu.in/overview117.html" target="_self">Overview</a></li><li><a href="https://jmieti.edu.in/infrastructure118.html" target="_self">Infrastructure</a></li><li><a href="https://jmieti.edu.in/faculty119.html" target="_self">Faculty</a></li><li><a href="https://jmieti.edu.in/activities120.html" target="_self">Activities</a></li><li><a href="https://jmieti.edu.in/time-table121.html" target="_self">Time Table</a></li><li><a href="https://jmieti.edu.in/syllabus122.html" target="_self">Syllabus</a></li><li><a href="https://jmieti.edu.in/co-and-lesson-plans123.html" target="_self">CO and Lesson Plans</a></li><li><a href="https://jmieti.edu.in/mentor-mentee-list246.html" target="_self">Mentor-Mentee List</a></li></ul></li><li><a href="https://jmieti.edu.in/btech-civil-engineering.html" target="_self">B.Tech. (Civil Engineering)</a><ul><li><a href="https://jmieti.edu.in/overview73.html" target="_self">Overview</a></li><li><a href="https://jmieti.edu.in/infrastructure71.html" target="_self">Infrastructure</a></li><li><a href="https://jmieti.edu.in/faculty72.html" target="_self">Faculty</a></li><li><a href="https://jmieti.edu.in/activities74.html" target="_self">Activities</a></li><li><a href="https://jmieti.edu.in/time-table75.html" target="_self">Time Table</a></li><li><a href="https://jmieti.edu.in/syllabus76.html" target="_self">Syllabus</a></li><li><a href="https://jmieti.edu.in/co-and-lesson-plans77.html" target="_self">CO and Lesson Plans</a></li><li><a href="https://jmieti.edu.in/mentor-mentee-list247.html" target="_self">Mentor-Mentee List</a></li></ul></li><li><a href="https://jmieti.edu.in/applied-sciencehumanities.html" target="_self">Applied Science &amp; Humanities</a><ul><li><a href="https://jmieti.edu.in/overview140.html" target="_self">Overview</a></li><li><a href="https://jmieti.edu.in/infrastructure141.html" target="_self">Infrastructure</a></li><li><a href="https://jmieti.edu.in/faculty142.html" target="_self">Faculty</a></li><li><a href="https://jmieti.edu.in/activities143.html" target="_self">Activities</a></li><li><a href="https://jmieti.edu.in/time-table144.html" target="_self">Time Table</a></li><li><a href="https://jmieti.edu.in/syllabus145.html" target="_self">Syllabus</a></li><li><a href="https://jmieti.edu.in/co-and-lesson-plans146.html" target="_self">CO and Lesson Plans</a></li></ul></li><li><a href="https://jmieti.edu.in/bachelor-of-computer-applications-bca.html" target="_self">Bachelor of Computer Applications (BCA)</a><ul><li><a href="https://jmieti.edu.in/overview215.html" target="_self">Overview</a></li><li><a href="https://jmieti.edu.in/infrastructure216.html" target="_self">Infrastructure</a></li><li><a href="https://jmieti.edu.in/faculty217.html" target="_self">Faculty</a></li><li><a href="https://jmieti.edu.in/activities218.html" target="_self">Activities</a></li><li><a href="https://jmieti.edu.in/time-table219.html" target="_self">Time Table</a></li><li><a href= ...
# </td>
# </tr>
# </table>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown orange">
# <a href="placement-record.html"> Placements </a>
# <ul class="box-dropdown parent-arrow dropdown-menu">
# <li>
# <div class="box-wrapper bg-orange">
# <div class="mheading">INSIDE Placements</div>
# <table class="menu-megabox">
# <tr>
# <td>
# <img alt="product" src="https://jmieti.edu.in/templates/jmieti/images/img2.jpg"/>
# <div class="text">
#                                             The T&amp;P cell works round the clock to ensure that students of the institute get placed in reputed companies on lucrative terms. T&amp;P cell works relentlessly towards the ultimate goal of students’ employment across various...</div>
# <a class="btn btn-dark btn-circled btn-xs" href="placement-record.html">Read More</a>
# </td>
# <td>
# <ul class="nosubmenu">
# <ul><li><a href="https://jmieti.edu.in/placement-record.html" target="_self">Placement Record</a></li><li><a href="https://jmieti.edu.in/placement-rules.html" target="_self">Placement Rules</a></li><li><a href="https://jmieti.edu.in/industry-interaction.html" target="_self">Industry Interaction</a></li><li><a href="https://jmieti.edu.in/placement-associates.html" target="_self">Placement Associates</a></li><li><a href="https://jmieti.edu.in/placement-cell.html" target="_self">Placement Cell</a></li><li><a href="https://jmieti.edu.in/placement-brochure.html" target="_self">Placement Brochure</a></li></ul> </ul>
# </td>
# </tr>
# </table>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown green">
# <a href="centre-of-excellence.html"> Campus Life </a>
# <ul class="box-dropdown parent-arrow dropdown-menu">
# <li>
# <div class="box-wrapper bg-green">
# <div class="mheading">INSIDE Campus Life</div>
# <table class="menu-megabox">
# <tr>
# <td>
# <img alt="product" src="https://jmieti.edu.in/templates/jmieti/images/img3.jpg"/>
# <div class="text">
#                                                 The campus life at JMIETI nurtures rich tradition of creativity, culture, drama and arts. The activities on campus are diverse and varied from academic to extra-curricular. Over 50+ clubs and societies are available for you...</div>
# <a class="btn btn-dark btn-circled btn-xs" href="centre-of-excellence.html">Read More</a>
# </td>
# <td>
# <ul class="nosubmenu">
# <ul><li><a href="https://jmieti.edu.in/centre-of-excellence.html" target="_self">Centre of Excellence</a></li><li><a href="https://jmieti.edu.in/central-facilities.html" target="_self">Central Facilities</a></li><li><a href="https://jmieti.edu.in/infrastructure88.html" target="_self">Infrastructure</a></li><li><a href="https://jmieti.edu.in/activities89.html" target="_self">Activities</a></li><li><a href="https://jmieti.edu.in/clubs-societiescell.html" target="_self">Clubs, Societies &amp; Cell</a><ul><li><a href="https://jmieti.edu.in/clubssocieties.html" target="_self">Clubs &amp; Societies</a></li><li><a href="https://www.jmieti.edu.in/downloads/files/n6828298e944ac.PDF" target="_blank">Club Activity Calendar</a></li><li><a href="https://jmieti.edu.in/social-works.html" target="_self">Social Works</a></li><li><a href="https://jmieti.edu.in/entrepreneurship-development-cell.html" target="_self">Entrepreneurship Development Cell</a></li></ul></li><li><a href="https://jmieti.edu.in/sports.html" target="_self">Sports</a></li></ul> </ul>
# </td>
# </tr>
# </table>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header-nav">
# <div class="header-nav-wrapper navbar-scrolltofixed">
# <div class="container">
# <nav class="menuzord" id="menuzord">
# <ul class="menuzord-menu">
# <li><a href="javascript:void(0)">About Us</a>
# <div class="megamenu megamenu-quarter-width">
# <!--<h4 class="megamenu-col-title">INSIDE ABOUT US</h4>-->
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/profile.html" target="_self">Profile</a></li><li><a href="https://jmieti.edu.in/director-message.html" target="_self">Director Message</a></li><li><a href="https://jmieti.edu.in/board-of-governors.html" target="_self">Board of Governors</a></li><li><a href="https://jmieti.edu.in/achievements.html" target="_self">Achievements</a></li><li><a href="https://jmieti.edu.in/demography-of-students.html" target="_self">Demography of Students</a></li></ul>
# </ul>
# </div>
# <!--<div class="col6">
#                       <article class="post clearfix">
#                         <div class="entry-header">
#                           <div class="post-thumb"> <img class="img-responsive" src="https://jmieti.edu.in/templates/jmieti/images/about-menu-img.jpg" alt=""> </div>
#                         </div>
#                         <div class="entry-content">
#                           <p class="">Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna et sed aliqua</p>
#                           <a class="btn btn-dark btn-theme-colored" href="#">read more..</a> </div>
#                       </article>
#                     </div>-->
# </div>
# </div>
# </li>
# <li><a href="#">Society / Social Responsibility</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/blood-donation-movement.html" target="_self">Blood Donation Movement</a></li><li><a href="https://jmieti.edu.in/mukand-health-care-project.html" target="_self">Mukand Health Care Project</a></li><li><a href="https://jmieti.edu.in/medical-services.html" target="_self">Medical Services</a></li><li><a href="https://jmieti.edu.in/go-paperless.html" target="_self">Go Paperless</a></li><li><a href="https://jmieti.edu.in/tree-plantation-drives.html" target="_self">Tree Plantation Drives</a></li><li><a href="https://jmieti.edu.in/fee-help.html" target="_self">Fee Help</a></li><li><a href="https://jmieti.edu.in/interest-free-study-loan.html" target="_self">Interest Free Study Loan</a></li><li><a href="https://jmieti.edu.in/charity.html" target="_self">Charity</a></li><li><a href="https://jmieti.edu.in/book-bank-scheme.html" target="_self">Book Bank Scheme</a></li><li><a href="https://jmieti.edu.in/adoption-scheme.html" target="_self">Adoption Scheme</a></li><li><a href="https://jmieti.edu.in/preeti-bhoj.html" target="_self">Preeti Bhoj</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li><a href="#">Administration</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/committees.html" target="_self">Committees</a></li><li><a href="https://jmieti.edu.in/whom-to-consult.html" target="_self">Whom to Consult</a></li><li><a href="https://jmieti.edu.in/extension-of-approvals.html" target="_self">Extension of Approvals</a></li><li><a href="https://jmieti.edu.in/mandatory-disclosure.html" target="_self">Mandatory Disclosure</a></li><li><a href="https://jmieti.edu.in/controller-of-examination.html" target="_self">Controller of Examination</a></li><li><a href="https://jmieti.edu.in/finance-officer.html" target="_self">Finance Officer</a></li><li><a href="https://jmieti.edu.in/career.html" target="_self">Career</a></li><li><a href="https://jmieti.edu.in/list-of-holidays-2026.html" target="_self">List of Holidays-2026</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li><a href="#">Academics</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/academic-calendar.html" target="_self">Academic Calendar</a></li><li><a href="https://jmieti.edu.in/professional-membershipsmous.html" target="_self">Professional Memberships &amp; MoUs</a></li><li><a href="https://jmieti.edu.in/guest-lecturesworkshops.html" target="_self">Guest Lectures &amp; Workshops</a></li><li><a href="https://jmieti.edu.in/rulesregulations.html" target="_self">Rules &amp; Regulations</a></li><li><a href="https://jmieti.edu.in/ed-cell.html" target="_self">ED Cell</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li><a href="#">Gallery</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/photo-gallery.html" target="_self">Photo Gallery</a></li><li><a href="https://jmieti.edu.in/video-gallery.html" target="_self">Video Gallery</a></li><li><a href="https://jmieti.edu.in/media-clippings.html" target="_self">Media Clippings</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li><a href="#">Useful Links</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/application-forms.html" target="_self">Application Forms</a></li><li><a href="https://jmieti.edu.in/sc-st-complaint-form.html" target="_self">SC/ ST Complaint Form</a></li><li><a href="https://jmieti.edu.in/online-grievance-redressal28.html" target="_self">Online Grievance Redressal</a></li><li><a href="https://www.jmieti.edu.in/downloads/files/n66a22598c7e8c.pdf" target="_blank">List of Engineering Books</a></li><li><a href="https://jmieti.edu.in/other-links.html" target="_self">Other Links</a></li><li><a href="https://jmieti.edu.in/nirf.html" target="_self">NIRF</a></li><li><a href="https://jmieti.edu.in/social-media-logins111.html" target="_self">Social Media Logins</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li><a href="#">Alumni</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="?fn=alumni-meet" target="_self">Interactions</a><ul><li><a href="https://jmieti.edu.in/alumni-meet.html" target="_self">Alumni Meet</a></li><li><a href="https://jmieti.edu.in/placement-activities.html" target="_self">Placement Activities</a></li><li><a href="https://jmieti.edu.in/alumni-entrepreneur.html" target="_self">Alumni Entrepreneur</a></li><li><a href="https://jmieti.edu.in/guest-lectures-and-workshops.html" target="_self">Guest Lectures and Workshops</a></li></ul></li><li><a href="https://jmieti.edu.in/alumni-chapter.html" target="_self">Alumni Chapter</a></li><li><a href="https://jmieti.edu.in/registration-form.html" target="_self">Registration Form</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li><a href="#">Contact Us</a>
# <div class="megamenu megamenu-quarter-width">
# <div class="megamenu-row">
# <div class="col12">
# <ul class="list-dashed list-icon">
# <ul><li><a href="https://jmieti.edu.in/contact-address.html" target="_self">Contact Address</a></li></ul>
# </ul>
# </div>
# </div>
# </div>
# </li></ul>
# </nav>
# </div>
# </div>
# </div>
# </header><div id="preloader">
# <div id="spinner">
# <div class="preloader-dot-loading">
# <div class="cssload-loading"><i></i><i></i><i></i><i></i></div>
# </div>
# </div>
# <div class="btn btn-default btn-sm" id="disable-preloader">Disable Preloader</div>
# </div>
# <div class="main-content">
# <section id="home">
# <div class="container pt-0 pr-10 pl-10 pb-0">
# <div class="rev_slider_wrapper" data-alias="news-gallery34" id="rev_slider_home_wrapper" style="margin:0px auto;background-color:#ffffff;padding:5px 0px;margin-top:0px;margin-bottom:0px;">
# <div class="rev_slider" data-version="5.0.7" id="rev_slider_home" style="display:none;">
# <ul>
# <li data-easein="default" data-easeout="default" data-fsmasterspeed="1500" data-fsslotamount="7" data-fstransition="fade" data-index="rs-1" data-masterspeed="default" data-rotate="0" data-saveperformance="off" data-slotamount="default" data-thumb="images/slide1.jpg" data-title="" data-transition="fade"> <img alt="" class="rev-slidebg" data-bgfit="cover" data-bgparallax="10" data-bgposition="center center" data-bgrepeat="no-repeat" data-no-retina="" src="https://jmieti.edu.in/templates/jmieti/images/slide1.jpg"/>
# <div class="tp-caption tp-resizeme text-white rs-parallaxlevel-0" data-fontsize="['13','13','14','14']" data-fontweight="['500','500','400','400']" data-height="none" data-hoffset="['900','800','100','30']" data-lineheight="['30','30','30','30']" data-mask_in="x:0px;y:0px;s:inherit;e:inherit;" data-mask_out="x:0;y:0;s:inherit;e:inherit;" data-responsive_offset="on" data-splitin="none" data-splitout="none" data-start="1000" data-transform_idle="o:1;" data-transform_in="y:[-100%];z:0;rX:0deg;rY:0;rZ:0;sX:1;sY:1;skX:0;skY:0;s:1500;e:Power3.easeInOut;" data-transform_out="auto:auto;s:1000;e:Power3.easeInOut;" data-voffset="['360','290','260','260']" data-whitespace="wrap" data-width="['210','210','210','210']" data-x="['left','left','left','left']" data-y="['top','top','top','top']" id="slide-1-layer-4" style="z-index: 7;">
# <div class="bg-black slidecont" style="width: 260px; padding: 20px 10px 10px 15px;">
# <p>An investment in knowledge <br/>pays the best interest.<br/> <strong>Benjamin Franklin</strong></p>
# </div>
# </div>
# </li>
# <li data-easein="default" data-easeout="default" data-fsmasterspeed="1500" data-fsslotamount="7" data-fstransition="fade" data-index="rs-4" data-masterspeed="default" data-rotate="0" data-saveperformance="off" data-slotamount="default" data-thumb="images/slide5.jpg" data-title="" data-transition="fade"> <img alt="" class="rev-slidebg" data-bgfit="cover" data-bgparallax="10" data-bgposition="center center" data-bgrepeat="no-repeat" data-no-retina="" src="https://jmieti.edu.in/templates/jmieti/images/slide5.jpg"/>
# <div class="tp-caption tp-resizeme text-white rs-parallaxlevel-0" data-fontsize="['13','13','14','14']" data-fontweight="['500','500','400','400']" data-height="none" data-hoffset="['900','800','100','30']" data-lineheight="['30','30','30','30']" data-mask_in="x:0px;y:0px;s:inherit;e:inherit;" data-mask_out="x:0;y:0;s:inherit;e:inherit;" data-responsive_offset="on" data-splitin="none" data-splitout="none" data-start="1000" data-transform_idle="o:1;" data-transform_in="y:[-100%];z:0;rX:0deg;rY:0;rZ:0;sX:1;sY:1;skX:0;skY:0;s:1500;e:Power3.easeInOut;" data-transform_out="auto:auto;s:1000;e:Power3.easeInOut;" data-voffset="['360','290','260','260']" data-whitespace="wrap" data-width="['210','210','210','210']" data-x="['left','left','left','left']" data-y="['top','top','top','top']" id="slide-1-layer-4" style="z-index: 7;">
# <div class="bg-black slidecont" style="width: 260px; padding: 20px 10px 10px 15px;">
# <p>Real knowledge is to know the<br/>extent of one's ignorance.<br/> <strong> Confusius</strong></p>
# </div>
# </div>
# </li>
# <li data-easein="default" data-easeout="default" data-fsmasterspeed="1500" data-fsslotamount="7" data-fstransition="fade" data-index="rs-2" data-masterspeed="default" data-rotate="0" data-saveperformance="off" data-slotamount="default" data-thumb="images/slide2.jpg" data-title="" data-transition="fade"> <img alt="" class="rev-slidebg" data-bgfit="cover" data-bgparallax="10" data-bgposition="center center" data-bgrepeat="no-repeat" data-no-retina="" src="https://jmieti.edu.in/templates/jmieti/images/slide2.jpg"/>
# <div class="tp-caption tp-resizeme text-white rs-parallaxlevel-0" data-fontsize="['13','13','14','14']" data-fontweight="['500','500','400','400']" data-height="none" data-hoffset="['900','800','100','30']" data-lineheight="['30','30','30','30']" data-mask_in="x:0px;y:0px;s:inherit;e:inherit;" data-mask_out="x:0;y:0;s:inherit;e:inherit;" data-responsive_offset="on" data-splitin="none" data-splitout="none" data-start="1000" data-transform_idle="o:1;" data-transform_in="y:[-100%];z:0;rX:0deg;rY:0;rZ:0;sX:1;sY:1;skX:0;skY:0;s:1500;e:Power3.easeInOut;" data-transform_out="auto:auto;s:1000;e:Power3.easeInOut;" data-voffset="['360','290','260','260']" data-whitespace="wrap" data-width="['210','210','210','210']" data-x="['left','left','left','left']" data-y="['top','top','top','top']" id="slide-1-layer-4" style="z-index: 7;">
# <div class="bg-black slidecont" style="width: 260px; padding: 20px 10px 10px 15px;">
# <p>The roots of education are<br/>bitter, but the fruit is sweet.<br/> <strong>Aristotle</strong></p>
# </div>
# </div>
# </li>
# <li data-easein="default" data-easeout="default" data-fsmasterspeed="1500" data-fsslotamount="7" data-fstransition="fade" data-index="rs-3" data-masterspeed="default" data-rotate="0" data-saveperformance="off" data-slotamount="default" data-thumb="images/slide3.jpg" data-title="" data-transition="fade"> <img alt="" class="rev-slidebg" data-bgfit="cover" data-bgparallax="10" data-bgposition="center center" data-bgrepeat="no-repeat" data-no-retina="" src="https://jmieti.edu.in/templates/jmieti/images/slide3.jpg"/>
# <div class="tp-caption tp-resizeme text-white rs-parallaxlevel-0" data-fontsize="['13','13','14','14']" data-fontweight="['500','500','400','400']" data-height="none" data-hoffset="['900','800','100','30']" data-lineheight="['30','30','30','30']" data-mask_in="x:0px;y:0px;s:inherit;e:inherit;" data-mask_out="x:0;y:0;s:inherit;e:inherit;" data-responsive_offset="on" data-splitin="none" data-splitout="none" data-start="1000" data-transform_idle="o:1;" data-transform_in="y:[-100%];z:0;rX:0deg;rY:0;rZ:0;sX:1;sY:1;skX:0;skY:0;s:1500;e:Power3.easeInOut;" data-transform_out="auto:auto;s:1000;e:Power3.easeInOut;" data-voffset="['360','290','260','260']" data-whitespace="wrap" data-width="['210','210','210','210']" data-x="['left','left','left','left']" data-y="['top','top','top','top']" id="slide-1-layer-4" style="z-index: 7;">
# <div class="bg-black slidecont" style="width: 260px; padding: 20px 10px 10px 15px;">
# <p>Education is the manifestation<br/>of perfection already in man.<br/> <strong>Swami Vivekanand</strong></p>
# </div>
# </div>
# </li>
# <li data-easein="default" data-easeout="default" data-fsmasterspeed="1500" data-fsslotamount="7" data-fstransition="fade" data-index="rs-4" data-masterspeed="default" data-rotate="0" data-saveperformance="off" data-slotamount="default" data-thumb="images/slide4.jpg" data-title="" data-transition="fade"> <img alt="" class="rev-slidebg" data-bgfit="cover" data-bgparallax="10" data-bgposition="center center" data-bgrepeat="no-repeat" data-no-retina="" src="https://jmieti.edu.in/templates/jmieti/images/slide4.jpg"/>
# <div class="tp-caption tp-resizeme text-white rs-parallaxlevel-0" data-fontsize="['13','13','14','14']" data-fontweight="['500','500','400','400']" data-height="none" data-hoffset="['900','800','100','30']" data-lineheight="['30','30','30','30']" data-mask_in="x:0px;y:0px;s:inherit;e:inherit;" data-mask_out="x:0;y:0;s:inherit;e:inherit;" data-responsive_offset="on" data-splitin="none" data-splitout="none" data-start="1000" data-transform_idle="o:1;" data-transform_in="y:[-100%];z:0;rX:0deg;rY:0;rZ:0;sX:1;sY:1;skX:0;skY:0;s:1500;e:Power3.easeInOut;" data-transform_out="auto:auto;s:1000;e:Power3.easeInOut;" data-voffset="['360','290','260','260']" data-whitespace="wrap" data-width="['210','210','210','210']" data-x="['left','left','left','left']" data-y="['top','top','top','top']" id="slide-1-layer-4" style="z-index: 7;">
# <div class="bg-black slidecont" style="width: 260px; padding: 20px 10px 10px 15px;">
# <p>Real knowledge is to know the<br/>extent of one's ignorance.<br/> <strong> Confusius</strong></p>
# </div>
# </div>
# </li>
# </ul>
# <div class="tp-bannertimer tp-bottom" style="height: 5px; background-color: rgba(166, 216, 236, 1.00);"></div>
# </div>
# </div>
# <script type="text/javascript">
#                 var tpj = jQuery;
#                 var revapi34;
#                 tpj(document).ready(function() {
#                     if (tpj("#rev_slider_home").revolution == undefined) {
#                         revslider_showDoubleJqueryError("#rev_slider_home");
#                     } else {
#                         revapi34 = tpj("#rev_slider_home").show().revolution({
#                             sliderType: "standard",
#                             jsFileLocation: "js/revolution-slider/js/",
#                             sliderLayout: "default",
#                             dottedOverlay: "none",
#                             delay: 9000,
#                             navigation: {
#                                 keyboardNavigation: "on",
#                                 keyboard_direction: "horizontal",
#                                 mouseScrollNavigation: "off",
#                                 onHoverStop: "off",
#                                 touch: {
#                                     touchenabled: "on",
#                                     swipe_threshold: 75,
#                                     swipe_min_touches: 1,
#                                     swipe_direction: "horizontal",
#                                     drag_block_vertical: false
#                                 },
#                                 arrows: {
#                                     style: "gyges",
#                                     enable: true,
#                                     hide_onmobile: true,
#                                     hide_under: 600,
#                                     hide_onleave: true,
#                                     hide_delay: 100,
#                                     hide_delay_mobile: 1200,
#                                     tmp: '<div class="tp-title-wrap"></div>',
#                                     left: {
#                                         h_align: "left",
#                                         v_align: "center",
#                                         h_offset: 30,
#                                         v_offset: 0
#                                     },
#                                     right: {
#                                         h_align: "right",
#                                         v_align: "center",
#                                         h_offset: 30,
#                                         v_offset: 0
#                                     }
#                                 },
#                                 bullets: {
#                                     enable: false,
#                                     hide_onmobile: true,
#                                     hide_under: 600,
#                                     style: "metis",
#                                     hide_onleave: false,
#                                     direction: "horizontal",
#                                     h_align: "center",
#                                     v_align: "bottom",
#                                     h_offset: 0,
#                                     v_offset: 30,
#                                     space: 5,
#                                     tmp: '<span class="tp-bullet-img-wrap"></span>'
#                                 }
#                             },
#                             viewPort: {
#                                 enable: true,
#                                 outof: "pause",
#                                 visible_area: "80%"
#                             },
#                             responsiveLevels: [1240, 1024, 778, 480],
#                             gridwidth: [1240, 1024, 778, 480],
#                             gridheight: [600, 550, 500, 450],
#                             lazyType: "none",
#                             parallax: {
#                                 type: "scroll",
#                                 origo: "enterpoint",
#                                 speed: 400,
#                                 levels: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50],
#                             },
#                             shadow: 0,
#                             spinner: "off",
#                             stopLoop: "off",
#                             stopAfterLoops: -1,
#                             stopAtSlide: -1,
#                             shuffle: "off",
#                             autoHeight: "off",
#                             hideThumbsOnMobile: "on",
#                             hideSliderAtLimit: 0,
#                             hideCaptionAtLimit: 0,
#                             hideAllCaptionAtLilmit: 0,
#                             debugMode: false,
#                             fallbacks: {
#                                 simplifyAll: "off",
#                                 nextSlideOnWindowFocus: "off",
#                                 disableFocusListener: false,
#                             }
#                         });
#                     }
#                 });
#             </script>
# </div>
# </section>
# <section class="">
# <div class="container pt-30">
# <div class="section-content">
# <div class="row">
# <div class="col-md-7 col-sm-12 mrb-sm20">
# <h2 class="text-uppercase mt-0 mt-sm-30">Welcome to <span class="blue-color">JMIETI</span></h2>
# ...
# <div class="owl-carousel-2col testimonial-carousel" data-dots="true">
# <div class="item">
# <div class="testimonial pt-10 row">
# <div class="thumb pull-left mb-0 mr-0 pr-20 col-md-3"> <img alt="" class="img-thumbnail" src="https://jmieti.edu.in/templates/jmieti/images/sachin-baijwan.jpg"/></div>
# <div class="col-md-9">
# <p align="justify" class="mt-0">It has been great meeting new people at College and engaging with them in my academic studies. I found the teachers in all my subjects to be incredibly helpful, which significantly contributed towards my success. Throughout my four years, I have been encouraged by the teachers to participate in various workshops and sessions held, to widen my horizon in technical as well as in interpersonal skills. You get a lot of opportunities.Work hard to get it.</p>
# <p class="author mt-10">- <span class="blue-color">Er. Sachin Baijwan,</span> <br> <small><em class="text-gray">Batch 14-18<br/>Junior Engineer, Irrigation &amp; Water Resources Department, Jagadhari</em></small></br></p>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="testimonial pt-10 row">
# <div class="thumb pull-left mb-0 mr-0 pr-20 col-md-3"> <img alt="" class="img-thumbnail" src="https://jmieti.edu.in/templates/jmieti/images/vishal-mittal.jpg" width="135"/></div>
# <div class="col-md-9">
# <p align="justify" class="mt-0">Obviously it's natural to be skeptical about selecting the appropriate college to build your career. By God's grace, I landed on the JMIETI Website. The way in which all faculty members treat me from the very first day, I really felt that these people can guide me better than anyone to become a good professional. I took a leap of faith and decided to pursue my graduation in this prestigious institution. I was always loaded with amazing information from the ebooks and every other relevant study materials provided in the library , energized by all the fresh new training programs, and guest lectures.Really, I didn't join an organization, I joined a family.</p>
# <p class="author mt-10">- <span class="blue-color">Vishal Mittal </span> <br/> <small><em class="text-gray">Batch 16-20<br/>Congruex, Mohali</em></small></p>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="testimonial pt-10 row">
# <div class="thumb pull-left mb-0 mr-0 pr-20 col-md-3"> <img alt="" class="img-thumbnail" src="https://jmieti.edu.in/templates/jmieti/images/harshit-arora.jpg" width="135"/></div>
# <div class="col-md-9">
# <p align="justify" class="mt-0">JMIETI provides a ladder to go ahead with education which supports us throughout our life; it makes us different from other applicants and gives us opportunities to excel in life. I am happy to be an employee of Zapbild.</p>
# <p class="author mt-10">- <span class="blue-color">Harshit Arora</span> <br/> <small><em class="text-gray">CSE Deptt. 2015-19</em></small></p>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="testimonial pt-10 row">
# <div class="thumb pull-left mb-0 mr-0 pr-20 col-md-3"> <img alt="" class="img-thumbnail" src="https://jmieti.edu.in/templates/jmieti/images/anirudh-sharma.jpg" width="135"/></div>
# <div class="col-md-9">
# <p align="justify" class="mt-0">I am really influenced by the quality education and placement at JMIETI. I was enlightened by great insight of the eminent teachers. I strongly suggest JMIETI to all the aspirants for there bright future. I work with Telemune Software Solution Pvt. Ltd.</p>
# <p class="author mt-10">- <span class="blue-color">Anirudh Sharma</span> <br/> <small><em class="text-gray">CSE Deptt., Batch 2015-19</em></small></p>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="testimonial pt-10 row">
# <div class="thumb pull-left mb-0 mr-0 pr-20 col-md-3"> <img alt="" class="img-thumbnail" src="https://jmieti.edu.in/templates/jmieti/images/anshika-garg.jpg" width="135"/></div>
# <div class="col-md-9">
# <p align="justify" class="mt-0">The B.Tech in Computer Science from faculty of JMIETI is highly industry-oriented and provides a wide gamut of knowledge. The 4 years spent here were full of learning opportunities with the right blend of fun and academics. Our teachers were the best mentors who motivated us in every stage. They also helped me getting placed in Crazy club animation studio Pvt Ltd.., Delhi. JMIETI provides us various platforms to showcase our skills and talents. I thoroughly enjoyed my student life while my Graduation degree.</p>
# <p class="author mt-10">- <span class="blue-color">Anshika Garg</span> <br/> <small><em class="text-gray">CSE Deptt., Batch-2015-19</em></small></p>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="testimonial pt-10 row">
# <div class="thumb pull-left mb-0 mr-0 pr-20 col-md-3"> <img alt="" class="img-thumbnail" src="https://jmieti.edu.in/templates/jmieti/images/mukund-chhoker.jpg" width="135"/></div>
# <div class="col-md-9">
# <p align="justify" class="mt-0">It was a great experience studying at JMIETI Radaur, a memory to cherish for lifetime. My experience at JMIETI was full of learning and grooming. Being an affiliation of global University that is Kurukshetra University, It gave me an opportunity to meet different kind of people from around the world and learnt many things from them. I am thankful to all the faculties, mentors and entire SET department for providing us with quality education. I am also grateful to Faculty Members for organising placements in this pandemic and helping me to become a Online Digital Marketer as a Freelancer in the field of Web Development and Digital Marketing. Overall it was a great experience and lifetime memory at JMIETI Radaur. If you want to make a career in CSE I would highly recommend you to join JMIETI.</p>
# <p class="author mt-10">- <span class="blue-color">Mukund Chhoker </span> <br/> <small><em class="text-gray">B.Tech. (CSE), 2017-2021</em></small></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="cta-wrap">
# <div class="cta-backgrounds">
# <div class="cta-section cta1" style=""></div>
# <div class="cta-section cta2" style=""></div>
# <div class="cta-section cta3" style=""></div>
# <div class="cta-section cta4" style=""></div>
# </div>
# <div class="cta-content">
# <div class="cta-section animater cta1">
# <div class="cta-content-inner">
# <div class="widget dark">
# <h4 class="widget-title">JMIETI, Radaur</h4>
# <p class="text-white">Chota Bans, Radaur-135133 <br/>(Distt. Yamuna Nagar) Haryana <br><br/> +91-8295905215<br/>+91-8295905208<br/><br/>director@jmieti.edu.in<br/></br></p>
# </div>
# </div>
# </div>
# <div class="cta-section animater cta2">
# <div class="cta-content-inner">
# <div class="widget dark">
# <h4 class="widget-title">Why JMIETI?</h4>
# <div class="flist">
# <ul class="list-white">
# <li><a href="digitized-campus.html">Digitized Campus</a></li>
# <!--<li><a href="center-of-excellence.html">Centres of Excellence</a></li>-->
# <li><a href="affordability.html">Affordability</a></li>
# <li><a href="healthysecure-campus.html">Healthy &amp; Secure Campus</a></li>
# <li><a href="beyond-the-book.html">Beyond the Book</a></li>
# <li><a href="additional-input.html">Additional Input</a></li>
# <li><a href="mous-with-reputed-organizations.html">MOUs with reputed organizations</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cta-section animater cta3">
# <div class="cta-content-inner">
# <div class="widget dark">
# <h4 class="widget-title">Useful Links</h4>
# <div class="flist">
# <ul class="list-white">
# <!--<li><a href="https://forms.gle/twJ2pbBPsEfZk76K6" target="_blank">SC/ ST Complaint Form</a></li>-->
# <li><a href="https://www.jmieti.edu.in/sc-st-complaint-form.html">SC/ ST Complaint Form</a></li>
# <!--<li><a href="grievance-redressal-form.html">Online Grievance Redressal</a></li>-->
# <li><a href="https://www.jmieti.edu.in/online-grievance-redressal28.html">Online Grievance Redressal</a></li>
# <!--<li><a href="https://www.tcsion.com/SelfServices/" target="_blank">ERP Login</a></li>-->
# <li><a href="https://panel.okiedokiepay.com/Login" target="_blank">ERP Login</a></li>
# <!--<li><a href="https://www.tcsion.com/LX//login#lx" target="_blank">Digital Learning</a></li>-->
# <li><a href="https://www3.digialm.com//EForms/configuredHtml/33/51954/login.html" target="_blank">Online Fee Payment</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cta-section animater cta4">
# <div class="cta-content-inner">
# <div class="widget">
# <h4 class="widget-title">Follow Us on</h4>
# <ul class="styled-icons icon-bordered icon-lg">
# <li class="border-radius-10px"><a href="https://www.facebook.com/jmietiinstitute" target="_blank"><i class="fa fa-facebook"></i></a></li>
# <li><a href="https://twitter.com/jmietiradaur" target="_blank"><i class="fa fa-twitter"></i></a></li>
# <li><a href="https://www.instagram.com/jmietiofficial/" target="_blank"><i class="fa fa-instagram"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--<div align="center">
#             </div>-->
# <!-- <div id="promoModal1" class="modal-promo-box mfp-hide bg-img-cover" data-bg-img="images/bg/bg1.jpg">
#         <div><img src="https://jmieti.edu.in/templates/jmieti/img/pop-up-new.jpg" alt=""></div>
#         <strong> Click <a href="https://data.odpay.in/odforms1/form/JMIETIRegistrationForm/formperma/X6MgbHJiKET6kkngmYP71A3bpOjNut2LevH-540YF0M" target="_blank" style="color:#8B0000;">HERE</a> for Registration</strong>
#     </div>
#     <div class="on-pageload-popup-promobox" data-target="#promoModal1"></div>-->
# </div>
# <!-- Footer -->
# <footer class="footer pt-0 pb-20" id="footer">
# <div class="footer-bottom">
# <div class="container pt-0 pb-30">
# <div class="row">
# <div class="col-md-12 text-center" style="color:#ffffff; background-color:#3d3d3d;">
# <div class="col-md-3 text-center">
# <a href="termsconditions.html">Terms &amp; Conditions</a>
# </div>
# <div class="col-md-3 text-center">
# <a href="use-of-information.html">Use of Information</a>
# </div>
# <div class="col-md-3 text-center">
# <a href="disclaimer.html">Disclaimer</a>
# </div>
# <div class="col-md-3 text-center">
# <a href="privacy-policy.html">Privacy Policy</a>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 text-center">
# <div class="widget no-border m-0">
# <ul class="list-inline sm-text-center mt-5">
# <p class="font-13 m-0">Copyright ©2021 JMIETI. All Rights Reserved</p>
# <li class="font-12">
#                                 Website Designed by : <a href="http://inetbusinesshub.com" target="_blank">iNET</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <a class="scrollToTop" href="#"><i class="fa fa-angle-up"></i></a>
# </div>
# <!-- end wrapper -->
# <div class="sticky-container">
# <ul class="stickyside">
# <!--<li style="font-size:16px; padding:10px;"><a href="https://www.tcsion.com/SelfServices/" target="_blank"> <i class="fa fa-pencil-square-o" aria-hidden="true"></i> &nbsp; ERP Login </a></li>-->
# <li style="font-size:16px; padding:10px;"><a href="https://panel.okiedokiepay.com/Login" target="_blank"> <i aria-hidden="true" class="fa fa-pencil-square-o"></i>   ERP Login </a></li>
# <li style="font-size:16px; padding:10px;"><a href="https://app.okiedokiepay.com/#!/632432f4709a582eace80876/entityLandingPage" target="_blank"> <i aria-hidden="true" class="fa fa-inr"></i>   Online Payment </a></li>
# <li style="font-size:16px; padding:10px;"><a href="https://www.aicte-india.org/bureaus/jk" target="_blank"> <i aria-hidden="true" class="fa fa-graduation-cap"></i>   PMSSS (J&amp;K) </a></li>
# <!--<li style="font-size:16px; padding:10px;"><a href="https://data.odpay.in/odforms1/form/JMIETIAdmissionForm/formperma/5BRy363AsT1blIMzP2olFSLnXB6cquyVJ_PjpaHpsxE" target="_blank"> <i class="fa fa-pencil-square-o" aria-hidden="true"></i> &nbsp; Registration 2025 </a></li>-->
# <li style="font-size:16px; padding:10px;"><a href="nirf.html"> <i aria-hidden="true" class="fa fa-pencil-square-o"></i>   NIRF </a></li>
# <li style="font-size:16px; padding:10px;"><a href="https://data.odpay.in/odforms1/form/JMIETIRegistrationForm/formperma/X6MgbHJiKET6kkngmYP71A3bpOjNut2LevH-540YF0M" target="_blank"> <i aria-hidden="true" class="fa fa-pencil-square-o"></i>   Registration 2026 </a></li>
# <!--<li style="font-size:16px; padding:10px;"><a href="https://maps.app.goo.gl/sMtnvhfSUx135H127" target="_blank"> <i class="fa fa-pencil-square-o" aria-hidden="true"></i> &nbsp;  360 Degree View </a></li>-->
# <li style="font-size:16px; padding:10px;"><a href="https://maps.app.goo.gl/Fn9dqmRyPC73LKSz7" target="_blank"> <i aria-hidden="true" class="fa fa-pencil-square-o"></i>   360 Degree View </a></li>
# </ul>
# </div>
# <div class="newsTicker">
# <div class="">
# <div class="row">
# <div class="col-md-2">
# <div class="nt-heading font-roboto">IN NEWS</div>
# </div>
# <div class="col-md-10">
# <marquee behavior="scroll" direction="left" height="30px" id="nticker" onmouseout="javascript:nticker.start();" onmouseover="javascript:nticker.stop();" scrollamount="7" width="100%">
#                     • <a class="marqueeH" href="#" style="">JMIETI | Approved by All India Council for Technical Education (AICTE) &amp; Department of Technical Education (DTE), Haryana. Affiliated to KU Kurukshetra.</a>                      </marquee>
# </div>
# </div>
# </div>
# </div>
# <!-- Footer Scripts -->
# <!-- JS | Custom script for all pages -->
# <script src="https://jmieti.edu.in/templates/jmieti/js/custom.js"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/jquery-ui.min.js"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/bootstrap.min.js"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.actions.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.carousel.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.kenburn.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.layeranimation.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.migration.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.navigation.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.parallax.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.slideanims.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/revolution-slider/js/extensions/revolution.extension.video.min.js" type="text/javascript"></script>
# <script src="https://jmieti.edu.in/templates/jmieti/js/jquery.mobile-menu.min.js"></script>
# <script>
#     jQuery(document).ready(function($) {
#         $("#mobile-menu").mobileMenu({
#             MenuWidth: 250,
#             SlideSpeed: 300,
#             WindowsMaxWidth: 991,
#             PagePush: true,
#             FromLeft: true,
#             Overlay: true,
#             CollapseMenu: true,
#             ClassName: "mobile-menu"
#         });
#     });
# </script>
# <script>
#     jQuery(document).ready(function($) {
#         var alterClass = function() {
#             var ww = document.body.clientWidth;
#             if (ww < 800) {
#                 $('.cta-section').removeClass('skewed');
#             } else if (ww >= 801) {
#                 $('.cta-section').addClass('skewed');
#             };
#         };
#         $(window).resize(function() {
#             alterClass();
#         });
#         //Fire it when the page first loads:
#         alterClass();
#     });
#     $('ul.colormenu li').hover(function() {
#         $(this).find('.dropdown-menu').stop(true, true).delay(200).fadeIn(500);
#     }, function() {
#         $(this).find('.dropdown-menu').stop(true, true).delay(200).fadeOut(500);
#     });
# </script>
# </body>
# </html>
