# %%
import yfinance as yf
import pandas as pd

# %%
stock = "AAPL"
start_date = '2022-01-01'
end_date = '2023-01-01'

data = yf.download(stock, start=start_date, end=end_date)
data.reset_index(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   AAPL        AAPL        AAPL        AAPL       AAPL
# 0      2022-01-03  178.270325  179.122459  174.058687  174.176216  104487900
# 1      2022-01-04  176.007782  179.181217  175.439697  178.877588   99310400
# 2      2022-01-05  171.325989  176.468119  171.051743  175.919628   94537600
# 3      2022-01-06  168.466019  171.698219  168.113415  169.151633   96904000
# 4      2022-01-07  168.632507  170.562032  167.515931  169.337715   86709100
# ..            ...         ...         ...         ...         ...        ...
# 246    2022-12-23  129.900299  130.451974  127.713291  128.974267   63814900
# 247    2022-12-27  128.097519  129.457014  126.806990  129.427462   69007800
# 248    2022-12-28  124.166786  129.082622  123.999315  127.742834   85438400
# 249    2022-12-29  127.683739  128.540804  125.831682  126.087812   75703700
# 250    2022-12-30  127.998985  128.018692  125.536148  126.501586   77034200
#
# [251 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.plot(data['Date'], data['Close'], label='Closing Price')
plt.title(f'{stock} Closing Prices from {start_date} to {end_date}')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()
